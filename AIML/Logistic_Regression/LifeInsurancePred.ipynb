# %% [markdown]
# <h2 style="color:green"
# align="center"> Predicting if a person would buy life insurance based on his age using logistic regression</h2>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\HP\\Desktop\\AIML\\Datasets\\insurance_data.csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='+', color='black')

# %%
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size=0.8)

# %%
x_train
# Out:
#     age
# 9    61
# 25   54
# 3    52
# 13   29
# 26   23
# 22   40
# 6    55
# 24   50
# 5    56
# 16   25
# 12   27
# 11   28
# 10   18
# 23   45
# 8    62
# 1    25
# 21   26
# 0    22
# 20   21
# 18   19
# 15   55

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 7    60
# 2    47
# 17   58
# 14   49
# 4    46
# 19   18

# %%
y_pred = model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.1072013 , 0.8927987 ],
#        [0.34873718, 0.65126282],
#        [0.13128509, 0.86871491],
#        [0.29846803, 0.70153197],
#        [0.37528959, 0.62471041],
#        [0.93764542, 0.06235458]])

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
y_test
# Out:
# 7     1
# 2     1
# 17    1
# 14    1
# 4     1
# 19    0
# Name: bought_insurance, dtype: int64

# %%
y_pred
# Out:
# array([1, 1, 1, 1, 1, 0])

# %% [markdown]
# **model.coef_ indicates value of m in y = m*x+b equation**

# %%
model.coef_
# Out:
# array([[0.11500446]])

# %% [markdown]
# **model.intercept_**

# %%
model.intercept_
# Out:
# array([-4.78061515])

# %% [markdown]
# **Lets defined sigmoid function now and do the math with hand**

# %%
import math 
def sigmoid(x):
    return 1 / ( 1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.12 * age - 4.91
    y = sigmoid(z)
    return y

# %%
age = 35

# %%
prediction_function(age)
# Out:
# 0.3295988401911314

# %% [markdown]
# **0.485 is less than 0.5 which means pearson with 35 age will not busy insurance**

# %%
age = 43
prediction_function(age)
# Out:
# 0.5621765008857981

# %% [markdown]
# **0.485 is more than 0.5 which means pearson with 43 age will not busy insurance**
